# %%
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
% matplotlib inline

# %%
data = pd.read_csv('Data/QA.csv')

# %%
G=nx.DiGraph()
G.add_edges_from(edges)
fig = plt.figure(figsize=(30, 30), dpi=100)
nx.draw_networkx(G)

# %%
edges = []
for i in range(0,len(data)):
    edges.append((data.AnswerProvider[i],data.AnswerSeeker[i]))

# %%
data.head(2)
# Out:
#    AnswerProvider  AnswerSeeker
# 0              23            10
# 1              34             6

# %%
data.isnull().sum()
# Out:
# AnswerProvider    0
# AnswerSeeker      0
# dtype: int64
